# %%
print ("Task 1")
# Out:
# Task 1

# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/brpoo/Downloads/Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Identify and handle missing values using .isnull() in Python or filters in Excel.

print(df.isnull().sum())
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#Remove duplicate rows using .drop_duplicates() or Excel’s “Remove Duplicates”.

df.drop_duplicates()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Standardize text values like gender, country names, etc. Convert date formats to a consistent type (e.g., dd-mm-yyyy).

df['Gender'] = df['Gender'].str.lower().str.strip()

# %%
# Rename column headers to be clean and uniform (e.g., lowercase, no spaces).

df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
#Check and fix data types (e.g., age should be int, date as datetime).

print(df.dtypes)
# Out:
# customerid                 int64
# gender                    object
# age                        int64
# annual_income_(k$)         int64
# spending_score_(1-100)     int64
# dtype: object
